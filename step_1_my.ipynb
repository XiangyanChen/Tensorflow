# %%
import tensorflow as tf
import numpy as np
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
x_data = np.random.rand(2, 100) # (2 X 100)
np.shape(x_data)
# Out:
# (2, 100)

# %%
y_data = np.dot([[0.01, 0.02]], x_data) + 30.1 #(1 X 100)
np.shape(y_data)
# Out:
# (1, 100)

# %%
np.random.uniform(-1, 1, [1, 2])
# Out:
# array([[-0.09139463, -0.51138258]])

# %%
x = tf.placeholder(tf.float32, shape=[2, 100], name="input_x") #(2 X 100)
y = tf.placeholder(tf.float32, shape=[1, 100], name="input_y") #(1 X 100)
b = tf.Variable(tf.zeros([1]), name="variable_b") #(1,1)
W = tf.Variable(tf.random_uniform([1, 2], -1, 1), name="variable_W") #(2 X 1)
y_prediction = tf.add(tf.matmul(W, x, name="mul_y"),b, name="add_y") #(1 X 100)

# %%
loss = tf.reduce_mean(tf.square(y - y_prediction)) #损失函数
optimizer = tf.train.GradientDescentOptimizer(0.5) #优化器
train_op = optimizer.minimize(loss) #训练

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for step in range(10000):
        loss_, _, W_, b_, _ = sess.run([loss, train_op, W, b, y_prediction], feed_dict={x:x_data, y:y_data})
        if step % 50 == 0:
            print("%d epoch" % step, loss_, W_, b_)
    writer = tf.summary.FileWriter("./graphs/step1_graph", sess.graph)
    #writer.add_graph(sess.graph)
    writer.close()
# Out:
# 0 epoch 935.9035 [[-0.81048775 -0.14802623]] [0.]
# 50 epoch 0.06272715 [[0.51693887 0.7031864 ]] [29.44872]
# 100 epoch 0.00022760719 [[0.03974299 0.06178625]] [30.06082]
# 150 epoch 8.257687e-07 [[0.01177657 0.02252793]] [30.097641]
# 200 epoch 3.0277443e-09 [[0.01010704 0.02015292]] [30.099857]
# 250 epoch 1.23327485e-11 [[0.01000628 0.02000925]] [30.099993]
# 300 epoch 4.7293723e-12 [[0.01000394 0.02000503]] [30.099995]
# 350 epoch 4.7293723e-12 [[0.01000398 0.02000503]] [30.099995]
# 400 epoch 4.7293723e-12 [[0.01000401 0.02000501]] [30.099995]
# 450 epoch 4.7293723e-12 [[0.01000403 0.02000499]] [30.099995]
# 500 epoch 4.7293723e-12 [[0.01000404 0.02000497]] [30.099995]
# 550 epoch 4.7293723e-12 [[0.01000406 0.02000495]] [30.099995]
# 600 epoch 4.765752e-12 [[0.01000407 0.02000493]] [30.099995]
# 650 epoch 4.7293723e-12 [[0.01000407 0.02000491]] [30.099995]
# 700 epoch 4.7293723e-12 [[0.01000409 0.02000489]] [30.099995]
# ...
